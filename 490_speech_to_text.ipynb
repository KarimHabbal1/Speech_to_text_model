# %% [markdown]
# Loading Timit Training Dataset using DeepLake

# %%
# !pip install "deeplake<4"
# !pip install av
# !pip install deeplake[audio]

import deeplake
Training_Data_Set = deeplake.load("hub://activeloop/timit-train")
# Out:
# Requirement already satisfied: deeplake<4 in /usr/local/lib/python3.10/dist-packages (3.9.30)
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.10/dist-packages (from deeplake<4) (1.26.4)
# Requirement already satisfied: pillow~=10.4.0 in /usr/local/lib/python3.10/dist-packages (from deeplake<4) (10.4.0)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.10/dist-packages (from deeplake<4) (1.35.36)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from deeplake<4) (8.1.7)
# Requirement already satisfied: pathos in /usr/local/lib/python3.10/dist-packages (from deeplake<4) (0.3.3)
# Requirement already satisfied: humbug>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from deeplake<4) (0.3.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from deeplake<4) (4.66.6)
# Requirement already satisfied: lz4 in /usr/local/lib/python3.10/dist-packages (from deeplake<4) (4.3.3)
# Requirement already satisfied: pyjwt in /usr/local/lib/python3.10/dist-packages (from deeplake<4) (2.10.0)
# Requirement already satisfied: aioboto3>=10.4.0 in /usr/local/lib/python3.10/dist-packages (from deeplake<4) (13.2.0)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.10/dist-packages (from deeplake<4) (1.6.0)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from deeplake<4) (2.9.2)
# Requirement already satisfied: libdeeplake==0.0.149 in /usr/local/lib/python3.10/dist-packages (from deeplake<4) (0.0.149)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from libdeeplake==0.0.149->deeplake<4) (0.3.9)
# Requirement already satisfied: aiobotocore==2.15.2 in /usr/local/lib/python3.10/dist-packages (from aiobotocore[boto3]==2.15.2->aioboto3>=10.4.0->deeplake<4) (2.15.2)
# Requirement already satisfied: aiofiles>=23.2.1 in /usr/local/lib/python3.10/dist-packages (from aioboto3>=10.4.0->deeplake<4) (24.1.0)
# Requirement already satisfied: botocore<1.35.37,>=1.35.16 in /usr/local/lib/python3.10/dist-packages (from aiobotocore==2.15.2->aiobotocore[boto3]==2.15.2->aioboto3>=10.4.0->deeplake<4) (1.35.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.2 in /usr/local/lib/python3.10/dist-packages (from aiobotocore==2.15.2->aiobotocore[boto3]==2.15.2->aioboto3>=10.4.0->deeplake<4) (3.11.2)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /usr/local/lib/python3.10/dist-packages (from aiobotocore==2.15.2->aiobotocore[boto3]==2.15.2->aioboto3>=10.4.0->deeplake<4) (1.16.0)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from aiobotocore==2.15.2->aiobotocore[boto3]==2.15.2->aioboto3>=10.4.0->deeplake<4) (0.12.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from boto3->deeplake<4) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from boto3->deeplake<4) (0.10.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from humbug>=0.3.1->deeplake<4) (2.32.3)
# Requirement already satisfied: ppft>=1.7.6.9 in /usr/local/lib/python3.10/dist-packages (from pathos->deeplake<4) (1.7.6.9)
# Requirement already satisfied: pox>=0.3.5 in /usr/local/lib/python3.10/dist-packages (from pathos->deeplake<4) (0.3.5)
# Requirement already satisfied: multiprocess>=0.70.17 in /usr/local/lib/python3.10/dist-packages (from pathos->deeplake<4) (0.70.17)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->deeplake<4) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic->deeplake<4) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic->deeplake<4) (4.12.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore<1.35.37,>=1.35.16->aiobotocore==2.15.2->aiobotocore[boto3]==2.15.2->aioboto3>=10.4.0->deeplake<4) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.10/dist-packages (from botocore<1.35.37,>=1.35.16->aiobotocore==2.15.2->aiobotocore[boto3]==2.15.2->aioboto3>=10.4.0->deeplake<4) (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->humbug>=0.3.1->deeplake<4) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->humbug>=0.3.1->deeplake<4) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->humbug>=0.3.1->deeplake<4) (2024.8.30)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.15.2->aiobotocore[boto3]==2.15.2->aioboto3>=10.4.0->deeplake<4) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.15.2->aiobotocore[boto3]==2.15.2->aioboto3>=10.4.0->deeplake<4) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.15.2->aiobotocore[boto3]==2.15.2->aioboto3>=10.4.0->deeplake<4) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.15.2->aiobotocore[boto3]==2.15.2->aioboto3>=10.4.0->deeplake<4) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.15.2->aiobotocore[boto3]==2.15.2->aioboto3>=10.4.0->deeplake<4) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.15.2->aiobotocore[boto3]==2.15.2->aioboto3>=10.4.0->deeplake<4) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.15.2->aiobotocore[boto3]==2.15.2->aioboto3>=10.4.0->deeplake<4) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.15.2->aiobotocore[boto3]==2.15.2->aioboto3>=10.4.0->deeplake<4) (4.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.35.37,>=1.35.16->aiobotocore==2.15.2->aiobotocore[boto3]==2.15.2->aioboto3>=10.4.0->deeplake<4) (1.16.0)
# Collecting av
#   Downloading av-13.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Downloading av-13.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.1/33.1 MB 31.7 MB/s eta 0:00:00
# Installing collected packages: av
# Successfully installed av-13.1.0
# Requirement already satisfied: deeplake[audio] in /usr/local/lib/python3.10/dist-packages (3.9.30)
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.10/dist-packages (from deeplake[audio]) (1.26.4)
# Requirement already satisfied: pillow~=10.4.0 in /usr/local/lib/python3.10/dist-packages (from deeplake[audio]) (10.4.0)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.10/dist-packages (from deeplake[audio]) (1.35.36)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from deeplake[audio]) (8.1.7)
# Requirement already satisfied: pathos in /usr/local/lib/python3.10/dist-packages (from deeplake[audio]) (0.3.3)
# Requirement already satisfied: humbug>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from deeplake[audio]) (0.3.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from deeplake[audio]) (4.66.6)
# Requirement already satisfied: lz4 in /usr/local/lib/python3.10/dist-packages (from deeplake[audio]) (4.3.3)
# Requirement already satisfied: pyjwt in /usr/local/lib/python3.10/dist-packages (from deeplake[audio]) (2.10.0)
# Requirement already satisfied: aioboto3>=10.4.0 in /usr/local/lib/python3.10/dist-packages (from deeplake[audio]) (13.2.0)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.10/dist-packages (from deeplake[audio]) (1.6.0)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from deeplake[audio]) (2.9.2)
# Requirement already satisfied: libdeeplake==0.0.149 in /usr/local/lib/python3.10/dist-packages (from deeplake[audio]) (0.0.149)
# Requirement already satisfied: av>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from deeplake[audio]) (13.1.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from libdeeplake==0.0.149->deeplake[audio]) (0.3.9)
# Requirement already satisfied: aiobotocore==2.15.2 in /usr/local/lib/python3.10/dist-packages (from aiobotocore[boto3]==2.15.2->aioboto3>=10.4.0->deeplake[audio]) (2.15.2)
# Requirement already satisfied: aiofiles>=23.2.1 in /usr/local/lib/python3.10/dist-packages (from aioboto3>=10.4.0->deeplake[audio]) (24.1.0)
# Requirement already satisfied: botocore<1.35.37,>=1.35.16 in /usr/local/lib/python3.10/dist-packages (from aiobotocore==2.15.2->aiobotocore[boto3]==2.15.2->aioboto3>=10.4.0->deeplake[audio]) (1.35.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.2 in /usr/local/lib/python3.10/dist-packages (from aiobotocore==2.15.2->aiobotocore[boto3]==2.15.2->aioboto3>=10.4.0->deeplake[audio]) (3.11.2)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /usr/local/lib/python3.10/dist-packages (from aiobotocore==2.15.2->aiobotocore[boto3]==2.15.2->aioboto3>=10.4.0->deeplake[audio]) (1.16.0)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from aiobotocore==2.15.2->aiobotocore[boto3]==2.15.2->aioboto3>=10.4.0->deeplake[audio]) (0.12.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from boto3->deeplake[audio]) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from boto3->deeplake[audio]) (0.10.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from humbug>=0.3.1->deeplake[audio]) (2.32.3)
# Requirement already satisfied: ppft>=1.7.6.9 in /usr/local/lib/python3.10/dist-packages (from pathos->deeplake[audio]) (1.7.6.9)
# Requirement already satisfied: pox>=0.3.5 in /usr/local/lib/python3.10/dist-packages (from pathos->deeplake[audio]) (0.3.5)
# Requirement already satisfied: multiprocess>=0.70.17 in /usr/local/lib/python3.10/dist-packages (from pathos->deeplake[audio]) (0.70.17)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->deeplake[audio]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic->deeplake[audio]) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic->deeplake[audio]) (4.12.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore<1.35.37,>=1.35.16->aiobotocore==2.15.2->aiobotocore[boto3]==2.15.2->aioboto3>=10.4.0->deeplake[audio]) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.10/dist-packages (from botocore<1.35.37,>=1.35.16->aiobotocore==2.15.2->aiobotocore[boto3]==2.15.2->aioboto3>=10.4.0->deeplake[audio]) (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->humbug>=0.3.1->deeplake[audio]) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->humbug>=0.3.1->deeplake[audio]) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->humbug>=0.3.1->deeplake[audio]) (2024.8.30)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.15.2->aiobotocore[boto3]==2.15.2->aioboto3>=10.4.0->deeplake[audio]) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.15.2->aiobotocore[boto3]==2.15.2->aioboto3>=10.4.0->deeplake[audio]) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.15.2->aiobotocore[boto3]==2.15.2->aioboto3>=10.4.0->deeplake[audio]) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.15.2->aiobotocore[boto3]==2.15.2->aioboto3>=10.4.0->deeplake[audio]) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.15.2->aiobotocore[boto3]==2.15.2->aioboto3>=10.4.0->deeplake[audio]) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.15.2->aiobotocore[boto3]==2.15.2->aioboto3>=10.4.0->deeplake[audio]) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.15.2->aiobotocore[boto3]==2.15.2->aioboto3>=10.4.0->deeplake[audio]) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.15.2->aiobotocore[boto3]==2.15.2->aioboto3>=10.4.0->deeplake[audio]) (4.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.35.37,>=1.35.16->aiobotocore==2.15.2->aiobotocore[boto3]==2.15.2->aioboto3>=10.4.0->deeplake[audio]) (1.16.0)
# -
# Opening dataset in read-only mode as you don't have write permissions.
# |
# This dataset can be visualized in Jupyter Notebook by ds.visualize() or at https://app.activeloop.ai/activeloop/timit-train
# -
# hub://activeloop/timit-train loaded successfully.

# %% [markdown]
# Citation

# %%
'''
CITATION
@inproceedings,
  title = {TIMIT Acoustic-Phonetic Continuous Speech Corpus},
  author = {John S. Garofolo, Lori F. Lamel, William M. Fisher, Jonathan G. Fiscus, David S. Pallett, Nancy L. Dahlgren, Victor Zue},
  booktitle = {Linguistic Data Consortium, },
  year = {1993}
}
'''

# %% [markdown]
# Messing around with the dataset

# %%
import librosa
import matplotlib.pyplot as plt
import numpy as np
import librosa.display

sample = Training_Data_Set[1]  #access the first sample


#access the audio waveform from the 'audios' tensor
def process_timit_sample(sample):

    audio = sample['audios'].numpy() #extract the audio waveform as a NumPy array
    texts = sample['texts'].numpy() #extract the corresponding text

    sr = 16000 #TIMIT dataset has a 16kHz sample rate
    if len(audio.shape) > 1:
            audio = audio.flatten()

    #plot the waveform
    plt.figure(figsize=(10, 4))
    librosa.display.waveshow(audio, sr=sr)
    plt.title('Waveform')
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')
    plt.show()

    fr = librosa.stft(audio) #forier transform
    s_db = librosa.amplitude_to_db(abs(fr),ref=np.max)

    plt.figure(figsize=(10, 4))
    librosa.display.specshow(s_db, sr=sr, x_axis='time', y_axis='log')
    plt.colorbar(format='%+2.0f dB')
    plt.title('Spectogram')
    plt.xlabel('Time (s)')
    plt.ylabel('Frequency (Hz)')
    plt.show()

process_timit_sample(sample)
